# %%
import os
os.system ("pip install simpletransformers")
import logging

from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs

# Loading the data and converting into the required format
import json

with open('/content/train.json', 'r') as f:
  train_data = json.load(f)

#train_data = [item for topic in train_data['data'] for item in topic['paragraphs']]


with open(r"test.json", "r") as read_file:
    test_data = json.load(read_file)

def model_name(model_type):
  if model_type == "bert":
      model_name = "bert-base-cased"

  elif model_type == "roberta":
      model_name = "roberta-base"

  elif model_type == "distilbert":
      model_name = "distilbert-base-cased"

  elif model_type == "distilroberta":
      model_type = "roberta"
      model_name = "distilroberta-base"

  elif model_type == "electra-base":
      model_type = "electra"
      model_name = "google/electra-base-discriminator"

  elif model_type == "electra-small":
      model_type = "electra"
      model_name = "google/electra-small-discriminator"

  elif model_type == "xlnet":
      model_name = "xlnet-base-cased"

  return model_name


#model_type="bert"
#model_name= "bert-base-cased"

def train_model(test_data, train_data, model_type, model_name, args=train_args ):
  ### Advanced Methodology
  model_name = model_type(model_name)
  model = QuestionAnsweringModel(
      model_type,model_name, args=train_args
  )

  # Train the model
  model.train_model(test_data, eval_data=train_data)
#  model.save_weights('/content/train.json/savefile')
  model.compile()
#  model.load_weights('/content/train/savefile')
#  return "model created"
  result, texts = model.eval_model(test_data)
  return result, texts


#def evaluate_model(test_data):
  # Evaluate the model
  # result, texts = model.eval_model(test_data)


inputlist = []
inputdict={}

qaslist = []

qas1 = {}
qas2 = {}
qas3 = {}
qas4 = {}
qas5 = {}


inputdict ["context"] = request.form["context"]
qas1 ["qa1"]  = request.form["qa1"]
qas2 ["qa2"]  = request.form["qa2"]
qas3 ["qa3"]  = request.form["qa3"]
qas4 ["qa4"]  = request.form["qa4"]
qas5 ["qa5"]  = request.form["qa5"]

qas1 ["id"]  = str(time.time())_str(001)
qas2 ["id"]  = str(time.time())_str(002)
qas3 ["id"]  = str(time.time())_str(003)
qas4 ["id"]  = str(time.time())_str(004)
qas5 ["id"]  = str(time.time())_str(005)

qaslist.extend([qas1, qas2, qas3, qas4, qas5])
inputdict["qas"] = qaslist


inputlist = []
inputlist.append(inputlist)

ListwithContextDictQASlistwithQuestionIdDict = inputdict

def predict_model(ListwithContextDictQASlistwithQuestionIdDict):
  # Make predictions with the model
  answers, probabilities = model.predict(ListwithContextDictQASlistwithQuestionIdDict)
  return answers


def train2 (train_args, model_name, model_type):
  model = QuestionAnsweringModel(train_args, model_name, model_type)
  model.train_model(train_data[:0.4])
# Out:
#   File "<ipython-input-2-7f8edc8af6ba>", line 89
#     qas1 ["id"]  = str(time.time())_str(001)
#                                       ^
# SyntaxError: invalid syntax

# %% [markdown]
# Methods to train, evaluate and predict data using methods

# %%
### Advanced Methodology
train_args = {
    "reprocess_input_data": True,
    "overwrite_output_dir": True,
    "use_cached_eval_features": True,
    "output_dir": f"outputs/{model_type}",
    "best_model_dir": f"outputs/{model_type}/best_model",
    "evaluate_during_training": True,
    "max_seq_length": 128,
    "num_train_epochs": 15,
    "evaluate_during_training_steps": 1000,
    "wandb_project": "Question Answer Application",
    "wandb_kwargs": {"name": model_name},
    "save_model_every_epoch": False,
    "save_eval_checkpoints": False,
    "n_best_size":3,
    # "use_early_stopping": True,
    # "early_stopping_metric": "mcc",
    # "n_gpu": 2,
    # "manual_seed": 4,
    # "use_multiprocessing": False,
    "train_batch_size": 128,
    "eval_batch_size": 64,
    # "config": {
    #     "output_hidden_states": True
    # }
}


train_args = {
      'learning_rate': 3e-5,
      'num_train_epochs': 3,
      'max_seq_length': 384,
      'doc_stride': 128,
      'overwrite_output_dir': True,
      'reprocess_input_data': False,
      'train_batch_size': 6,
      'gradient_accumulation_steps': 8,
  }
  model = QuestionAnsweringModel('bert', 'bert-base-uncased', args = train_args)

#      to_predict = [
#      {
#          "context": "Rangi nyeupe ni alama ya Amani, Kumwagika kwa damu wakati wa kupigania uhuru kunaonyeshwa kwa rangi Nyekundu, Rangi iliyo juu katika bendera ya Kenya huwa Nyeusi.", 
#          "qas": [
#              {
#                  "question": "Rangi nyeupe ni alama ya?", 
#                  "id": "0"
#              }
#            ],
#        }
#    ]
